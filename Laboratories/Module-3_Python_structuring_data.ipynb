# %%
# Import statements
import pandas as pd
import numpy as np
import seaborn as sns
import datetime
import jinja2
from matplotlib import pyplot as plt

# %%
# Read in the 2018 data.
df = pd.read_csv('/Users/michalbando/Downloads/Różne/IT/Google Advanced Data Analytics/Datasets/eda_structuring_with_python_dataset1.csv')
df.head()
# Out:
#          date  number_of_strikes center_point_geom
# 0  2018-01-03                194     POINT(-75 27)
# 1  2018-01-03                 41   POINT(-78.4 29)
# 2  2018-01-03                 33   POINT(-73.9 27)
# 3  2018-01-03                 38   POINT(-73.8 27)
# 4  2018-01-03                 92     POINT(-79 28)

# %%
# Convert the `date` column to datetime.
df['date'] = pd.to_datetime(df['date'])

# %%
df.drop_duplicates().shape
# Out:
# (3401012, 3)

# %%
# Sort by number of strikes in descending order.
df.sort_values(by='number_of_strikes', ascending=False).head(10)
# Out:
#              date  number_of_strikes  center_point_geom
# 302758 2018-08-20               2211  POINT(-92.5 35.5)
# 278383 2018-08-16               2142  POINT(-96.1 36.1)
# 280830 2018-08-17               2061  POINT(-90.2 36.1)
# 280453 2018-08-17               2031  POINT(-89.9 35.9)
# 278382 2018-08-16               1902  POINT(-96.2 36.1)
# 11517  2018-02-10               1899  POINT(-95.5 28.1)
# 277506 2018-08-16               1878  POINT(-89.7 31.5)
# 24906  2018-02-25               1833  POINT(-98.7 28.9)
# 284320 2018-08-17               1767    POINT(-90.1 36)
# 24825  2018-02-25               1741      POINT(-98 29)

# %%
# Identify the locations that appear most in the dataset.
df.center_point_geom.value_counts()
# Out:
# center_point_geom
# POINT(-81.5 22.5)     108
# POINT(-84.1 22.4)     108
# POINT(-82.5 22.9)     107
# POINT(-82.7 22.9)     107
# POINT(-82.5 22.8)     106
#                      ...
# POINT(-119.3 35.1)      1
# POINT(-119.3 35)        1
# POINT(-119.6 35.6)      1
# POINT(-119.4 35.6)      1
# POINT(-58.5 45.3)       1
# Name: count, Length: 170855, dtype: int64

# %%
# Identify the top 20 locations with most days of lightning.
df.center_point_geom.value_counts()[:20].rename_axis('unique_values').reset_index(name='counts').style.background_gradient()
# Out:
# <style type="text/css">
# #T_dfd62_row0_col1, #T_dfd62_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_dfd62_row2_col1, #T_dfd62_row3_col1 {
#   background-color: #045d92;
#   color: #f1f1f1;
# }
# #T_dfd62_row4_col1, #T_dfd62_row5_col1 {
#   background-color: #1379b5;
#   color: #f1f1f1;
# }
# #T_dfd62_row6_col1, #T_dfd62_row7_col1 {
#   background-color: #509ac6;
#   color: #f1f1f1;
# }
# #T_dfd62_row8_col1, #T_dfd62_row9_col1 {
#   background-color: #91b5d6;
#   color: #000000;
# }
# #T_dfd62_row10_col1 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_dfd62_row11_col1, #T_dfd62_row12_col1, #T_dfd62_row13_col1, #T_dfd62_row14_col1, #T_dfd62_row15_col1 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_dfd62_row16_col1, #T_dfd62_row17_col1, #T_dfd62_row18_col1, #T_dfd62_row19_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_dfd62">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dfd62_level0_col0" class="col_heading level0 col0" >unique_values</th>
#       <th id="T_dfd62_level0_col1" class="col_heading level0 col1" >counts</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfd62_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dfd62_row0_col0" class="data row0 col0" >POINT(-81.5 22.5)</td>
#       <td id="T_dfd62_row0_col1" class="data row0 col1" >108</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dfd62_row1_col0" class="data row1 col0" >POINT(-84.1 22.4)</td>
#       <td id="T_dfd62_row1_col1" class="data row1 col1" >108</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dfd62_row2_col0" class="data row2 col0" >POINT(-82.5 22.9)</td>
#       <td id="T_dfd62_row2_col1" class="data row2 col1" >107</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dfd62_row3_col0" class="data row3 col0" >POINT(-82.7 22.9)</td>
#       <td id="T_dfd62_row3_col1" class="data row3 col1" >107</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dfd62_row4_col0" class="data row4 col0" >POINT(-82.5 22.8)</td>
#       <td id="T_dfd62_row4_col1" class="data row4 col1" >106</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dfd62_row5_col0" class="data row5 col0" >POINT(-84.2 22.3)</td>
#       <td id="T_dfd62_row5_col1" class="data row5 col1" >106</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dfd62_row6_col0" class="data row6 col0" >POINT(-76 20.5)</td>
#       <td id="T_dfd62_row6_col1" class="data row6 col1" >105</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dfd62_row7_col0" class="data row7 col0" >POINT(-75.9 20.4)</td>
#       <td id="T_dfd62_row7_col1" class="data row7 col1" >105</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dfd62_row8_col0" class="data row8 col0" >POINT(-82.2 22.9)</td>
#       <td id="T_dfd62_row8_col1" class="data row8 col1" >104</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dfd62_row9_col0" class="data row9 col0" >POINT(-78 18.2)</td>
#       <td id="T_dfd62_row9_col1" class="data row9 col1" >104</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dfd62_row10_col0" class="data row10 col0" >POINT(-83.9 22.5)</td>
#       <td id="T_dfd62_row10_col1" class="data row10 col1" >103</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_dfd62_row11_col0" class="data row11 col0" >POINT(-84 22.4)</td>
#       <td id="T_dfd62_row11_col1" class="data row11 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_dfd62_row12_col0" class="data row12 col0" >POINT(-82 22.8)</td>
#       <td id="T_dfd62_row12_col1" class="data row12 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_dfd62_row13_col0" class="data row13 col0" >POINT(-82 22.4)</td>
#       <td id="T_dfd62_row13_col1" class="data row13 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_dfd62_row14_col0" class="data row14 col0" >POINT(-82.3 22.9)</td>
#       <td id="T_dfd62_row14_col1" class="data row14 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_dfd62_row15_col0" class="data row15 col0" >POINT(-78 18.3)</td>
#       <td id="T_dfd62_row15_col1" class="data row15 col1" >102</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_dfd62_row16_col0" class="data row16 col0" >POINT(-84.1 22.5)</td>
#       <td id="T_dfd62_row16_col1" class="data row16 col1" >101</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_dfd62_row17_col0" class="data row17 col0" >POINT(-75.5 20.6)</td>
#       <td id="T_dfd62_row17_col1" class="data row17 col1" >101</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_dfd62_row18_col0" class="data row18 col0" >POINT(-84.2 22.4)</td>
#       <td id="T_dfd62_row18_col1" class="data row18 col1" >101</td>
#     </tr>
#     <tr>
#       <th id="T_dfd62_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_dfd62_row19_col0" class="data row19 col0" >POINT(-76 20.4)</td>
#       <td id="T_dfd62_row19_col1" class="data row19 col1" >101</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Create two new columns.
df['week'] = df.date.dt.isocalendar().week
df['weekday'] = df.date.dt.day_name()
df.head()
# Out:
#         date  number_of_strikes center_point_geom  week    weekday
# 0 2018-01-03                194     POINT(-75 27)     1  Wednesday
# 1 2018-01-03                 41   POINT(-78.4 29)     1  Wednesday
# 2 2018-01-03                 33   POINT(-73.9 27)     1  Wednesday
# 3 2018-01-03                 38   POINT(-73.8 27)     1  Wednesday
# 4 2018-01-03                 92     POINT(-79 28)     1  Wednesday

# %%
# Calculate the mean count of lightning strikes for each weekday.
df[['weekday','number_of_strikes']].groupby(['weekday']).mean()
# Out:
#            number_of_strikes
# weekday
# Friday             13.349972
# Monday             13.152804
# Saturday           12.732694
# Sunday             12.324717
# Thursday           13.240594
# Tuesday            13.813599
# Wednesday          13.224568

# %%
# Define order of days for the plot.
weekday_order = ['Monday','Tuesday', 'Wednesday', 'Thursday','Friday','Saturday','Sunday']

# %%
# Create boxplots of strike counts for each day of week.
g = sns.boxplot(data=df,
            x='weekday',
            y='number_of_strikes',
            order=weekday_order,
            showfliers=False
            );
g.set_title('Lightning distribution per weekday (2018)');

# %%
# Import 2016–2017 data
df_2 = pd.read_csv('/Users/michalbando/Downloads/Różne/IT/Google Advanced Data Analytics/Datasets/eda_structuring_with_python_dataset2.csv')
df_2.head()
# Out:
#          date  number_of_strikes  center_point_geom
# 0  2016-01-04                 55  POINT(-83.2 21.1)
# 1  2016-01-04                 33  POINT(-83.1 21.1)
# 2  2016-01-05                 46  POINT(-77.5 22.1)
# 3  2016-01-05                 28  POINT(-76.8 22.3)
# 4  2016-01-05                 28    POINT(-77 22.1)

# %%
# Convert `date` column to datetime.
df_2['date'] = pd.to_datetime(df_2['date'])

# %%
# Create a new dataframe combining 2016–2017 data with 2018 data.
union_df = pd.concat([df.drop(['weekday','week'],axis=1), df_2], ignore_index=True)
union_df.head()
# Out:
#         date  number_of_strikes center_point_geom
# 0 2018-01-03                194     POINT(-75 27)
# 1 2018-01-03                 41   POINT(-78.4 29)
# 2 2018-01-03                 33   POINT(-73.9 27)
# 3 2018-01-03                 38   POINT(-73.8 27)
# 4 2018-01-03                 92     POINT(-79 28)

# %%
# Add 3 new columns.
union_df['year'] = union_df.date.dt.year
union_df['month'] = union_df.date.dt.month
union_df['month_txt'] = union_df.date.dt.month_name()
union_df.head()
# Out:
#         date  number_of_strikes center_point_geom  year  month month_txt
# 0 2018-01-03                194     POINT(-75 27)  2018      1   January
# 1 2018-01-03                 41   POINT(-78.4 29)  2018      1   January
# 2 2018-01-03                 33   POINT(-73.9 27)  2018      1   January
# 3 2018-01-03                 38   POINT(-73.8 27)  2018      1   January
# 4 2018-01-03                 92     POINT(-79 28)  2018      1   January

# %%
# Calculate total number of strikes per year
union_df[['year','number_of_strikes']].groupby(['year']).sum()
# Out:
#       number_of_strikes
# year
# 2016           41582229
# 2017           35095195
# 2018           44600989

# %%
# Calculate total lightning strikes for each month of each year.
lightning_by_month = union_df.groupby(['month_txt','year']).agg(
    number_of_strikes = pd.NamedAgg(column='number_of_strikes',aggfunc=sum)
    ).reset_index()

lightning_by_month.head()
# Out:
# /var/folders/77/bxgbvz0s0r14k6cfkqvfpr9m0000gn/T/ipykernel_37479/4141918718.py:2: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   lightning_by_month = union_df.groupby(['month_txt','year']).agg(
#   month_txt  year  number_of_strikes
# 0     April  2016            2636427
# 1     April  2017            3819075
# 2     April  2018            1524339
# 3    August  2016            7250442
# 4    August  2017            6021702

# %%
# Calculate total lightning strikes for each year.
lightning_by_year = union_df.groupby(['year']).agg(
  year_strikes = pd.NamedAgg(column='number_of_strikes',aggfunc=sum)
).reset_index()

lightning_by_year.head()
# Out:
# /var/folders/77/bxgbvz0s0r14k6cfkqvfpr9m0000gn/T/ipykernel_37479/1371192814.py:2: FutureWarning: The provided callable <built-in function sum> is currently using SeriesGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   lightning_by_year = union_df.groupby(['year']).agg(
#    year  year_strikes
# 0  2016      41582229
# 1  2017      35095195
# 2  2018      44600989

# %%
# Combine `lightning_by_month` and `lightning_by_year` dataframes into single dataframe.
percentage_lightning = lightning_by_month.merge(lightning_by_year,on='year')
percentage_lightning.head()
# Out:
#   month_txt  year  number_of_strikes  year_strikes
# 0     April  2016            2636427      41582229
# 1     April  2017            3819075      35095195
# 2     April  2018            1524339      44600989
# 3    August  2016            7250442      41582229
# 4    August  2017            6021702      35095195

# %%
# Create new `percentage_lightning_per_month` column.
percentage_lightning['percentage_lightning_per_month'] = (percentage_lightning.number_of_strikes/
                                                          percentage_lightning.year_strikes * 100.0)
percentage_lightning.head()
# Out:
#   month_txt  year  number_of_strikes  year_strikes  \
# 0     April  2016            2636427      41582229
# 1     April  2017            3819075      35095195
# 2     April  2018            1524339      44600989
# 3    August  2016            7250442      41582229
# 4    August  2017            6021702      35095195
#
#    percentage_lightning_per_month
# 0                        6.340273
# 1                       10.882045
# 2                        3.417725
# 3                       17.436396
# 4                       17.158195

# %%
plt.figure(figsize=(10,6))

month_order = ['January', 'February', 'March', 'April', 'May', 'June',
               'July', 'August', 'September', 'October', 'November', 'December']

sns.barplot(
    data = percentage_lightning,
    x = 'month_txt',
    y = 'percentage_lightning_per_month',
    hue = 'year',
    order = month_order )
plt.xlabel("Month")
plt.ylabel("% of lightning strikes")
plt.title("% of lightning strikes each Month (2016-2018)")
# Out:
# Text(0.5, 1.0, '% of lightning strikes each Month (2016-2018)')
